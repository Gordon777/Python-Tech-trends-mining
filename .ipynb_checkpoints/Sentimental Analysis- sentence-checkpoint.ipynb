# %%
# below is the sentiment analysis code rewritten for sentence-level analysis
# note the new module -- word_tokenize!
import nltk.data
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk import sentiment
from nltk import word_tokenize

# %%
# Next, we initialize VADER so we can use it within our Python script
sid = SentimentIntensityAnalyzer()
# We will also initialize our 'english.pickle' function and give it a short name
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
message_text = open(r"C:\Users\IDEA3C\Dropbox\Paper\論文\論文正式版\資料\Regtech100公司資料\編碼資料\2019-98.txt", "r", encoding="utf-8-sig").read()  # 导入需要计算的内容
# The tokenize method breaks up the paragraph into a list of strings. In this example, note that the tokenizer is confused by the absence of spaces after periods and actually fails to break up sentences in two instances. How might you fix that?
sentences = tokenizer.tokenize(message_text)
# We add the additional step of iterating through the list of sentences and calculating and printing polarity scores for each one.
for sentence in sentences:
        print(sentence)
        scores = sid.polarity_scores(sentence)
        for key in sorted(scores):
                print('{0}: {1}, '.format(key, scores[key]), end='')
        print()
# Out:
# Our Services
# W2 Global Data (W2) offer an extensive range of award winning products and services enabling organisations to conduct regulatory Know Your Customer (KYC), Anti-Money Laundering (AML) and fraud prevention Customer Due Diligence (CDD).
# compound: 0.4767, neg: 0.089, neu: 0.749, pos: 0.162,
# Our services include ID and Age verification, PEP and Sanctions screening and monitoring, document verification and facial comparison.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# W2’s data and services can be accessed via our flexible range of online portals; SAVI desktop, eKYChecker API and BSMaRT our on-going monitoring and screening tool.
# compound: 0.2263, neg: 0.0, neu: 0.929, pos: 0.071,
# Our award services include but are not limited to:
#
#
# Know Your Customer
# (KYC)
#
# Undertaking Know Your Customer (KYC) checks is an essential element of onboarding new customers, clients or partners.
# compound: 0.5022, neg: 0.0, neu: 0.868, pos: 0.132,
# Customer Due Diligence means taking steps to identify your customers and checking they are who they say they are.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# W2 can perform comprehensive checks on Individuals, Companies and Identity documents in real-time giving you actionable data before you choose to welcome them as a new customer.
# compound: 0.7506, neg: 0.0, neu: 0.757, pos: 0.243,
# Learn more...
#
# Anti-Money Laundering (AML)
#
# W2 offers compliance solutions to meet every point of the compliance journey – From on-boarding to ongoing alerts in changes in your customer base.
# compound: 0.1779, neg: 0.0, neu: 0.941, pos: 0.059,
# Our platform and services unifies the best available international Sanctions, Politically Exposed Persons (PEP), global watchlist and adverse media data into a single consumable package to help your business apply a true risk based approach, in a cost effective way.
# compound: 0.836, neg: 0.121, neu: 0.616, pos: 0.263,
# Learn more...
#
# ID Verification with Facial Comparison
#
# Facial comparison offers you a true alternative to traditional ID verification methods.
# compound: 0.4215, neg: 0.0, neu: 0.859, pos: 0.141,
# Bringing you the speed of eKYC checks, it gives you the power to confirm in real time that a prospect is the true holder of the document, avoids the geography boundaries that restricts other methods and delivers the newest functionality in compliance and anti-money laundering instruments.
# compound: 0.25, neg: 0.08, neu: 0.82, pos: 0.1,
# Learn more...
#
# Fraud Prevention
#
# Our services help protect individuals and organisations from the growing and increasingly sophisticated threat of fraud and financial crime.
# compound: -0.7096, neg: 0.362, neu: 0.374, pos: 0.264,
# With our UK & International Address Look up, Salacious Name Check, Email Risk Assessment and UK Postal Redirect Alert Database you can stay both compliant and safe from fraud.
# compound: -0.2023, neg: 0.169, neu: 0.686, pos: 0.146,
# Learn more...
#
# ID & Document Verification
#
# Providing one single integration for all your KYC document processing, our Document Verification services allows a cost effective means of verifying ID and Proof of Address documents, on a per-document basis; reducing fraud, increasing conversion and enhancing your back-office efficiency.
# compound: 0.2023, neg: 0.077, neu: 0.81, pos: 0.113,
# Learn more...
#
# Know Your Business (KYB)
#
# With comprehensive credit reports on companies around the world, W2 make managing your own credit risk an easy task.
# compound: 0.7906, neg: 0.065, neu: 0.621, pos: 0.314,
# Our Know Your Business (KYB) suite has been designed to provide finance and credit teams with all the tools and details needed to make informed, data-driven decisions.
# compound: 0.3818, neg: 0.0, neu: 0.909, pos: 0.091,
# Learn more...
#
# Know Your Customer (KYC)
# Our all-in-one KYC, compliance and anti-fraud solution solutions will help you comply with Know Your Customer (KYC) and Anti-Money Laundering (AML) regulations.
# compound: 0.6908, neg: 0.0, neu: 0.789, pos: 0.211,
# KYC policies are constantly expanding and KYC Checks have become very important globally as a tool to combat illegal transactions in the international finance field.
# compound: -0.6003, neg: 0.206, neu: 0.722, pos: 0.072,
# Our KYC checks allow companies to protect themselves from financial criminals and by ensuring that they are compliant with KYC laws.
# compound: 0.2263, neg: 0.136, neu: 0.623, pos: 0.242,
# Our online KYC technology eliminates slow, costly and inefficient KYC processes.
# compound: -0.1027, neg: 0.123, neu: 0.877, pos: 0.0,
# One API is all you need
# Our OneGateway product offers KYC, Compliance and Anti-Fraud from one simple API.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Schedule a call with us today to see how integration to a single platform offering instantaneous age and identity verification, AML checks, fraudulent behaviour analysis, black and white lists, affordability assessment, facial comparison and ongoing monitoring, all powered by state of the art machine learning and intelligence can improve your customer acquisition rates.
# compound: 0.8374, neg: 0.052, neu: 0.766, pos: 0.182,
# Global KYC Data
# Our KYC Service included hundreds of integrated KYC data sources to provide premium coverage for global Compliance And Anti-Fraud Globally.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# With just one integration you'll have access to hundreds of KYC Data sources, real-time verifications and analysis.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# W2 Global Data (W2) offer an extensive range of award winning products and services enabling organisations to conduct regulatory Know Your Customer (KYC), Anti-Money Laundering (AML) and fraud prevention Customer Due Diligence (CDD).
# compound: 0.4767, neg: 0.093, neu: 0.737, pos: 0.17,
# Our global KYC services include ID and Age verification, PEP and Sanctions screening and monitoring, document verification and facial comparison.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# AML Compliance
# W2 offers compliance solutions to meet every point of the compliance journey – From on-boarding to ongoing alerts in changes in your customer base.
# compound: 0.7804, neg: 0.0, neu: 0.771, pos: 0.229,
# Our platform and services unifies the best available international Sanctions, Politically Exposed Persons (PEP), global watchlist and adverse media data into a single consumable package to help your business apply a true risk based approach, in a cost effective way.
# compound: 0.836, neg: 0.121, neu: 0.616, pos: 0.263,
# Whether you are a small business or large enterprise, having confidence in a scalable, reliable compliance suite will allow your business to expand with confidence, while avoiding the ever increasing fines that regulators are issuing – the FCA alone issued fines totalling over £229 million in 2017.
# compound: 0.7506, neg: 0.083, neu: 0.714, pos: 0.203,
# It's never been more important to partner with the right organisation for compliance, and at W2, we pride ourselves in providing the right solution for your business.
# compound: 0.4388, neg: 0.059, neu: 0.787, pos: 0.154,
# Global Sanctions & Watchlists
# We offer a high-volume sanctions screening service to help businesses identify risks more effectively andstay compliant.
# compound: 0.5849, neg: 0.091, neu: 0.652, pos: 0.256,
# Our automated solution gives your business reliable sanctions data for client onboarding and ongoing monitoring, giving you the most important sanctions data and watchlists.
# compound: 0.6997, neg: 0.0, neu: 0.756, pos: 0.244,
# We deliver comprehensive sanctions checks that are easily implemented via a secure, world-class REST API.
# compound: 0.7003, neg: 0.0, neu: 0.618, pos: 0.382,
# With our solution you can easily configure checks based on risks relevant to your business, allowing you to reduce risk and stay compliant while avoiding over-screening.
# compound: -0.2263, neg: 0.204, neu: 0.65, pos: 0.146,
# Politically Exposed Person’s (PEPs) & Senior Political Figures
# Politically exposed persons (PEPs) and Senior Political Figures are individuals whose prominent position in public life, this can make them, associates and immediate family members vulnerable to corruption.
# compound: -0.0516, neg: 0.119, neu: 0.82, pos: 0.061,
# PEPs are considered high risk in today’s regulatory environment.
# compound: -0.2732, neg: 0.208, neu: 0.792, pos: 0.0,
# Financial institutions can be hit with very heavy fines if they conduct business with PEPs without sufficient KYC checks and a enhanced due diligence processes.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# To ensure your firm remains compliant at all times we provide an ongoing PEP monitoring service that will regularly check all your customers.
# compound: 0.3818, neg: 0.0, neu: 0.894, pos: 0.106,
# ID Verification with
# Facial Comparison
# Facial comparison offers you a true alternative to traditional ID verification methods.
# compound: 0.4215, neg: 0.0, neu: 0.843, pos: 0.157,
# Bringing you the speed of electronic Know Your Customer (eKYC) checks, it gives you the power to confirm in real time that a prospect is the true holder of the document, avoids the geography boundaries that restricts other methods and delivers the newest functionality in compliance and anti-money laundering instruments.
# compound: 0.25, neg: 0.074, neu: 0.833, pos: 0.093,
# 5 Simple Steps
#
# 1.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Account opening
# Customer provides image of ID document
#
# 2.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Confirmation
# Customer confirms that images are clear
#
# 3.
# compound: 0.3818, neg: 0.0, neu: 0.729, pos: 0.271,
# Selfie
# Customer provides a selfie that we live test
#
# 4.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Data processing
# Images are processed, analysed and compared
#
# 5.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Results
# Audit trail stored and the images destroyed
# Why use facial comparison?
# compound: -0.4939, neg: 0.225, neu: 0.775, pos: 0.0,
# Our technology extracts biometric and alphanumeric data contained in an identity document to authenticate it by applying 50+ forensic document-specific tests and utilizing the industry's largest document library (supporting 200+ countries).
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Working in real time, our product eliminates manual screening errors, speeds up the document inspection process and significantly reducing employee training, operating costs and customer inconvenience.
# compound: -0.5994, neg: 0.17, neu: 0.83, pos: 0.0,
# Employ our facial verification for address and age verification, to check against watch lists such as Interpol, Office of Foreign Assets Control (OFAC) and Politically Exposed Persons (PEP) to provide the utmost security or create your own custom list.
# compound: 0.5994, neg: 0.031, neu: 0.824, pos: 0.146,
# How to integrate?
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# W2’s facial comparison service that is available through web browser or software development kit (SDK) for integration into iOS and Android mobile apps.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# With access to the largest document template library available on the market as well as government level facial comparison technology, facial comparison technology offers superior ID verification while minimising the impact on the customer onboarding journey.
# compound: 0.6808, neg: 0.0, neu: 0.859, pos: 0.141,
# Fraud Prevention
# To be compliant with AML legislation, satisfactory fraud prevention and due diligence must be carried out to verify customers/individuals and transparent proof of these checks must be kept on file.
# compound: 0.0085, neg: 0.176, neu: 0.648, pos: 0.177,
# Our electronic checks help organisations meet their KYC and AML obligations when new accounts are opened and when existing customers need to be checked.
# compound: 0.8331, neg: 0.0, neu: 0.737, pos: 0.263,
# Our Fraud prevention services help protect individuals and organisations from the growing and increasingly sophisticated threat of fraud and financial crime.
# compound: -0.7096, neg: 0.381, neu: 0.341, pos: 0.278,
# Our UK & International Address Look up, Salacious Name Check, Email Risk Assessment and UK Postal Redirect Alert Database enable businesses to quickly and easily identify high-risk applicants and manage them appropriately.
# compound: 0.3612, neg: 0.061, neu: 0.807, pos: 0.133,
# Email Risk Assessment in Real-Time
# This service helps stop fraudsters while approving good customers.
# compound: -0.296, neg: 0.347, neu: 0.405, pos: 0.248,
# With email risk assessment, you can streamline approvals without the friction of asking for additional validation information.
# compound: -0.2732, neg: 0.116, neu: 0.884, pos: 0.0,
# Learn more...
#
# UK Postal Redirect Alert Database
# UK & International Address Lookup with NCOA® Alert file can help businesses identify suspicious activity at the point of an application for a product or service.
# compound: 0.5574, neg: 0.068, neu: 0.738, pos: 0.194,
# The data is highly effective at reducing the risk of fraud.
# compound: -0.3626, neg: 0.341, neu: 0.463, pos: 0.196,
# Learn more...
#
# Unusable and Salacious Names Removal
# This service helps stop fraudsters while approving good customers.
# compound: -0.0258, neg: 0.242, neu: 0.519, pos: 0.238,
# With email risk assessment, you can streamline approvals without the friction of asking for additional validation information.
# compound: -0.2732, neg: 0.116, neu: 0.884, pos: 0.0,
# Learn more...
#
# Know Your Business (eKYB)
# Quickly Evaluate the Financial Health of a Company.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# From deciding which prospects to pursue to maintaining a balanced portfolio, understanding the credit risk associated with each customer is vital to protecting your business.
# compound: 0.5994, neg: 0.072, neu: 0.687, pos: 0.241,
# With comprehensive credit reports on companies around the world, W2 make managing your own credit risk an easy task.
# compound: 0.7906, neg: 0.08, neu: 0.534, pos: 0.385,
# Our Know Your Business (KYB) suite has been designed to provide finance and credit teams with all the tools and details needed to make informed, data-driven decisions.
# compound: 0.3818, neg: 0.0, neu: 0.909, pos: 0.091,
# Protect and Grow Your Business
# Credit risk management can be a struggle for many businesses – they have to contend with factors such as late payment, bad debt and even corporate fraud.
# compound: -0.8316, neg: 0.333, neu: 0.516, pos: 0.15,
# You can build a robust credit risk platform by using W2’s accurate company information and credit intelligence to minimise risk and create new opportunities.
# compound: 0.8807, neg: 0.121, neu: 0.434, pos: 0.445,
# Nowadays, every customer expects assistance as quickly as possible.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# It is no longer acceptable to spend hours (or even days) on accommodating a new customer and their needs, therefore making a positive first impression is the first step in making to making your new customer is a happy customer.
# compound: 0.8519, neg: 0.048, neu: 0.7, pos: 0.252,
# Make credit decisions quickly and without hassle.
# compound: 0.3818, neg: 0.0, neu: 0.698, pos: 0.302,
# Avoid risks of late payment
# Early warning flags enable you to avoid late payers and pursue bad debt threats.
# compound: -0.9403, neg: 0.596, neu: 0.404, pos: 0.0,
# Improve Days Sales Outstanding
# Reduce your DSO through credit insights which help you identify late payers.
# compound: 0.9042, neg: 0.0, neu: 0.496, pos: 0.504,
# Spot opportunities
# Take advantage of good ‘payees and credit ratings’ to improve credit terms and encourage new business opportunities.
# compound: 0.9612, neg: 0.0, neu: 0.338, pos: 0.662,
# W2 for Third Party Screening
# Carry out supplier screening to check whether potential suppliers fit your risk criteria prior to working with them in order to safeguard your business from unnecessary risks.
# compound: 0.5574, neg: 0.108, neu: 0.692, pos: 0.2,
# With the very latest of business reports, you can blacklist customers and suppliers who do not meet your credit approval criteria to speed up your due diligence screening process.
# compound: 0.2302, neg: 0.068, neu: 0.836, pos: 0.096,
# Evaluating all third parties thoroughly and conducting vendor screening is essential to protecting your business.
# compound: 0.4019, neg: 0.0, neu: 0.838, pos: 0.162,
# ID and Document Verification / Validation
# We have ID and Document verification/validation and services designed to make identity checks quick and easy.
# compound: 0.4404, neg: 0.0, neu: 0.873, pos: 0.127,
# Many businesses, large and small, trust this services to simplify their ID checks, staying compliant and protecting themselves from fraud.
# compound: -0.128, neg: 0.151, neu: 0.717, pos: 0.131,
# Our Manual and Automatic ID checking products support Anti-Money Laundering (AML) and Know Your Customer (KYC) legislation.
# compound: 0.4019, neg: 0.0, neu: 0.856, pos: 0.144,
# Add document checking capabilities to your systems, apps or websites
# You can easily integrate our Document and ID checks into your own systems and processes.
# compound: 0.34, neg: 0.0, neu: 0.909, pos: 0.091,
# With our API, you can push images of passports, ID cards, visas and other ID documents for validation from within your own apps.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Our automatic and manual checking service is suitable for both small and large businesses.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Contact us today and we can help you find which ID checking service could work for your business, reviewing your frequency, location and volume requirements.
# compound: 0.4019, neg: 0.0, neu: 0.899, pos: 0.101,
# ID Verification with
# Facial Comparison
# Facial comparison offers you a true alternative to traditional ID verification methods.
# compound: 0.4215, neg: 0.0, neu: 0.843, pos: 0.157,
# Bringing you the speed of electronic Know Your Customer (eKYC) checks, it gives you the power to confirm in real time that a prospect is the true holder of the document, avoids the geography boundaries that restricts other methods and delivers the newest functionality in compliance and anti-money laundering instruments.
# compound: 0.25, neg: 0.074, neu: 0.833, pos: 0.093,
# Learn more...
#
# Products
# W2 provide a wide range of web-based, online screening tools and services to help organisations make quick, informed decisions about the people and organisations they are interacting with.
# compound: 0.4019, neg: 0.0, neu: 0.915, pos: 0.085,
# SAVI™
# Run Anti-Money Laundering and Customer Due Diligence checks in realtime.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# KYCchecker™
# Realtime ID verification of consumer and corporate customers around the globe.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# BSMART™
# Stay up to date by continuously cross-referencing your database against a number of datasets.
# compound: 0.0772, neg: 0.0, neu: 0.909, pos: 0.091,
