# %%
# -*- coding: utf-8 -*-
import re
import string
import operator

# %%
#剔除常用字函数
def isCommon(ngram):
    commonWords = ["the", "be", "and", "of", "a", "in", "to", "have",
                   "it", "i", "that", "for", "you", "he", "with", "on", "do", "say",
                   "this", "they", "is", "an", "at", "but","we", "his", "from", "that",
                   "not", "by", "she", "or", "as", "what", "go", "their","can", "who",
                   "get", "if", "would", "her", "all", "my", "make", "about", "know",
                   "will","as", "up", "one", "time", "has", "been", "there", "year", "so",
                   "think", "when", "which", "them", "some", "me", "people", "take", "out",
                   "into", "just", "see", "him", "your", "come", "could", "now", "than",
                   "like", "other", "how", "then", "its", "our", "two", "more", "these",
                   "want", "way", "look", "first", "also", "new", "because", "day", "more",
                   "use", "no", "man", "find", "here", "thing", "give", "many", "well"]

    if ngram in commonWords:
        return True
    else:
        return False

# %%
def cleanText(input):
    input = re.sub('\n+', " ", input).lower() # 匹配换行用空格替换成空格
    input = re.sub('\[[0-9]*\]', "", input) # 剔除类似[1]这样的引用标记
    input = re.sub(' +', " ", input) #  把连续多个空格替换成一个空格
    input = bytes(input,encoding="utf-8") # 把内容转换成utf-8格式以消除转义字符
    #input = input.decode("ascii", "ignore")
    return input

def cleanInput(input):
    input = cleanText(input)
    cleanInput = []
    input = input.split(' '.encode()) #以空格为分隔符，返回列表


    for item in input:
        item = item.strip(string.punctuation.encode()) # string.punctuation获取所有标点符号

        if len(item) > 1 or (item.lower() == 'a' or item.lower() == 'i'): #找出单词，包括i,a等单个单词
            cleanInput.append(item)
    return cleanInput

# %%
def getNgrams(input, n):
    input = cleanInput(input)

    output = {} # 构造字典
    for i in range(len(input)-n+1):
        ngramTemp = (b" ".join(input[i:i+n]).decode())

        if isCommon(ngramTemp.split()[0]) or isCommon(ngramTemp.split()[1]):
            pass
        else:
            if ngramTemp not in output: #词频统计
                output[ngramTemp] = 0 #典型的字典操作
            output[ngramTemp] += 1
    return output

#获取核心词在的句子
def getFirstSentenceContaining(ngram, content):
    #print(ngram)
    sentences = content.split(".")
    for sentence in sentences:
        if ngram in sentence:
            return sentence
    return ""

# %%
#对本地文件的读取，测试时候用，因为无需联网
content = open(r"C:\Users\IDEA3C\Dropbox\Paper\論文\論文正式版\資料\Regtech100公司資料\2019資料彙總.txt", "r", encoding="utf-8").read()  # 导入需要计算的内容
ngrams = getNgrams(content, 2)
sortedNGrams = sorted(ngrams.items(), key = operator.itemgetter(1), reverse=True) # reverse=True 降序排列
print(sortedNGrams)
for top3 in range(3):
    print ("###"+getFirstSentenceContaining(sortedNGrams[top3][0],content.lower())+"###")
# Out:
# [('due diligence', 109), ('risk management', 108), ('financial institutions', 95), ('machine learning', 81), ('regulatory compliance', 63), ('surety eco', 61), ('financial services', 60), ('risk assessment', 56), ('anti-money laundering', 56), ('false positives', 53), ('identity verification', 50), ('money laundering', 42), ('mifid ii', 41), ('regulatory requirements', 39), ('company information', 39), ('nice actimize', 39), ('data protection', 37), ('risk models', 36), ('market data', 35), ('case management', 35), ('single api', 34), ('data sources', 32), ('compliance program', 31), ('cio-applications-compliance-logo-1024x220 financial', 31), ('transaction monitoring', 30), ('sanctions screening', 30), ('aml compliance', 30), ('artificial intelligence', 29), ('across multiple', 29), ('audit trail', 29), ('digital identities', 29), ('beneficial ownership', 28), ('customer onboarding', 28), ('customer kyc', 28), ('compliance risk', 27), ('enhanced due', 26), ('best execution', 26), ('gdpr auto', 26), ('user experience', 26), ('fraud prevention', 26), ('data management', 25), ('compliance teams', 25), ('social media', 25), ('financial crime', 24), ('laundering aml', 24), ('document verification', 24), ('onboarding process', 23), ('gdpr compliance', 23), ('are required', 23), ('key features', 23), ('law enforcement', 23), ('beneficial owners', 23), ('politically exposed', 23), ('management system', 22), ('compliance requirements', 22), ('id document', 22), ('decision making', 22), ('client onboarding', 22), ('compliance programs', 21), ('data processing', 21), ('id verification', 21), ('customer due', 21), ('compliance obligations', 21), ('data risk', 21), ('million companies', 21), ('identity documents', 21), ('personal data', 20), ('suspicious activity', 20), ('customer data', 20), ('health check', 20), ('client data', 20), ('fraud management', 20), ('customer experience', 20), ('fully integrated', 19), ('behavioral biometrics', 19), ('digital identity', 19), ('financial strength', 19), ('wide range', 19), ('fraud detection', 19), ('theta lake', 19), ('regulatory environment', 18), ('risk assessments', 18), ('ensure compliance', 18), ('credit risk', 18), ('customer risk', 18), ('regulatory obligations', 17), ('sanctions lists', 17), ('risk appetite', 17), ('alt text', 17), ('best practices', 16), ('information security', 16), ('incident response', 16), ('program manual', 16), ('data privacy', 16), ('big data', 16), ('key benefits', 16), ('transfer pricing', 16), ('best practice', 15), ('compliance team', 15), ('risk scoring', 15), ('are automatically', 15), ('risk exposure', 15), ('fully compliant', 15), ('data subject', 15), ('regulatory change', 15), ('exposed persons', 15), ('reputational damage', 15), ('managed service', 15), ('regulatory changes', 14), ('company data', 14), ('compliance professionals', 14), ('management program', 14), ('compliance officers', 14), ('over 100', 14), ('data quality', 14), ('fully configurable', 14), ('management systems', 14), ('data collection', 14), ('complex regulatory', 14), ('audit trails', 14), ('regulated businesses', 14), ('kyc remediation', 14), ('manual processes', 14), ('third party', 14), ('solution provides', 14), ('compliance management', 14), ('risk based', 14), ('corporate structures', 14), ('natural language', 14), ('adverse media', 14), ('identity theft', 14), ('kyc checks', 14), ('risk monitoring', 13), ('data analytics', 13), ('business needs', 13), ('regulatory reporting', 13), ('reduce risk', 13), ('solutions are', 13), ('consulting services', 13), ('review process', 13), ('third parties', 13), ('full compliance', 13), ('business intelligence', 13), ('bsa/aml ecosystem', 13), ('software solution', 13), ('aml program', 13), ('risk control', 13), ('extensive corporate', 13), ('corporate group', 13), ('privacy data', 13), ('business verification', 13), ('facial comparison', 13), ('compliance processes', 12), ('business development', 12), ('track record', 12), ('risk-based a ...
# ###
#
# traditional project management
#
#
# our traditional project management assistance includes:
#
# guidance on it governance, regulatory compliance, and best practices;
# disaster recovery planning, including high-availability/active-active designs to meet investor-driven disaster recovery mandates;
# project roi analysis and risk assessment, including over/under budgeting reviews and realignment recommendations;
# it vendor and resource provider due diligence; and
# it budgeting for a particular division or the entire firm, including peer review studies, industry research/comparisons, and strategic planning for the alignment of staff, resource, and technology initiatives###
# ### examples include:
#
# marisk: the minimum requirements for risk management regulation (effective december 2005), states that positions in a banking book subject to market price risks must be valued at least quarterly###
# ### as a result, many financial institutions did not adapt to the advances in the models###
